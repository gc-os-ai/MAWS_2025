# %% [markdown]
# # Making Aptamers Without Selex (MAWS)

# %% [markdown]
# ## Description
#
# Welcome to the new version of MAWS! This notebook will guide you through the steps to run MAWS successfully. Please, be aware that the 3d structure prediction of the MAWS generated aptamer is not accurate, so we suggest to use our instructions on notebook `2_aptamer_folding_3dDNA` to generate a better one.
#
# ### INPUT: What do you need to run this notebook?
#
# You only need a **pdb file of your target molecule**, and it can be a protein, small molecule or lipid.
#
# ### OUTPUT: What will you get from this notebook?
#
# You will get the optimal predicted sequence of your aptamer (DNA or RNA) and a **pdb file containing both your target molecule and the aptamer**.
#
# Credits to:
# - The creators of MAWS: [Heidelberg iGEM team (2015)](https://2015.igem.org/Team:Heidelberg/software/maws)
# - The first improvement of the software: [Heidelberg iGEM team (2017)](https://2017.igem.org/Team:Heidelberg/Software/MAWS)
# - The second improvement of the software: [NU Kazakhstan iGEM team (2022)](https://2022.igem.wiki/nu-kazakhstan/software)

# %% [markdown]
# ### REMEMBER: change the Jupyter kernel to **`Python (AptaLoop)`**. See our README file for detailed information.

# %% [markdown]
# ## Define MAWS parameters
#
# You can edit the following cell and change the parameters to run the MAWS program

# %%
# Job name
job_name = "maws_aptamer"

# Number of nucleotides in the aptamer (default: 15)
nucleotides = 30

# Path to your pdb file
my_path = "../../data/pfoa.pdb"

# Aptamer type (DNA or RNA)
apt_type = "DNA"

# Molecule type (protein, organic or lipid)
mol_type = "organic"

# Name of your conda environment
env_name = "maws"

# Beta (default: 0.01)
beta = 0.01

# First chunk size (default: 5000)
chunk_1 = 5000

# Second chunk size (default: 5000)
chunk_2 = 5000

# %% [markdown]
# The following cell will run the MAWS program.

# %%
# %%bash -s "$job_name" "$nucleotides" "$my_path" "$apt_type" "$mol_type" "$env_name" "$beta" "$chunk_1" "$chunk_2"
# NBPATH=$(pwd)
# python $NBPATH/../../heidelberg_maws/MAWS2023.py -n $1 -nt $2 -p $3 -ta $4 -tm $5 -cenv $6 -b $7 -c1 $8 -c2 $9

# %%
# !python ../../heidelberg_maws/MAWS2023.py \
  --name "{job_name}" \
  --ntides {nucleotides} \
  --path "{my_path}" \
  --aptamertype "{apt_type}" \
  --moleculetype "{mol_type}" \
  --beta {beta} \
  --firstchunksize {chunk_1} \
  --secondchunksize {chunk_2}
# Out:
# /workspace/heidelberg_maws/Kernels.py:12: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def rotateKernel(positions, element, axis, angle):
# /workspace/heidelberg_maws/Kernels.py:33: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def translateKernel(positions, element, shift):
# /workspace/heidelberg_maws/Kernels.py:40: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def centerOfMass(positions):
# /workspace/heidelberg_maws/Kernels.py:44: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def radius(center, positions):
# /workspace/heidelberg_maws/Kernels.py:48: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def kullbackLeiblerDivergenceKernel(sample, reference_sample):
# /workspace/heidelberg_maws/Kernels.py:52: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def EntropyKernel(sample):
# /workspace/heidelberg_maws/Kernels.py:59: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def ZPS(sample, beta=0.001):
# /workspace/heidelberg_maws/Kernels.py:68: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def S(sample, beta=0.001):
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to gaff; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for pdb File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
#    Status: pass
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
# Info: Total number of electrons: 200; net charge: 0
#
# Running: /opt/conda/envs/maws/bin/sqm -O -i sqm.in -o sqm.out
#
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./leap.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading Mol2 file: ./pfoa.mol2
# Reading MOLECULE named LIG
# Loading parameters: ./LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking 'LIG'....
# Checking parameters for unit 'LIG'.
# Checking for bond parameters.
# Checking for angle parameters.
# Unit is OK.
#  Creating LIG.lib
# Building topology.
# Building atom parameters.
# Writing pdb file: LIG_tmp.pdb
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
#
# Welcome to antechamber 22.0: molecular input file processor.
#
# Info: acdoctor mode is on: check and diagnose problems in the input file.
# Info: The atom type is set to gaff; the options available to the -at flag are
#       gaff, gaff2, amber, bcc, and sybyl.
#
# -- Check Format for pdb File --
#    Status: pass
# -- Check Unusual Elements --
#    Status: pass
# -- Check Open Valences --
#    Status: pass
# -- Check Geometry --
#       for those bonded
#       for those not bonded
#    Status: pass
# -- Check Weird Bonds --
#    Status: pass
# -- Check Number of Units --
#    Status: pass
# acdoctor mode has completed checking the input file.
#
# Info: Total number of electrons: 200; net charge: 0
#
# Running: /opt/conda/envs/maws/bin/sqm -O -i sqm.in -o sqm.out
#
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./leap.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading Mol2 file: ./pfoa.mol2
# Reading MOLECULE named LIG
# Loading parameters: ./LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking 'LIG'....
# Checking parameters for unit 'LIG'.
# Checking for bond parameters.
# Checking for angle parameters.
# Unit is OK.
#  Creating LIG.lib
# Building topology.
# Building atom parameters.
# Writing pdb file: LIG_tmp.pdb
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 1 improper torsion applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# /opt/conda/envs/maws/lib/python3.10/site-packages/openmm/app/internal/amber_file_parser.py:1165: UserWarning: Non-optimal GB parameters detected for GB model OBC1
#   warnings.warn(
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 13 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# /opt/conda/envs/maws/lib/python3.10/site-packages/openmm/app/internal/amber_file_parser.py:1165: UserWarning: Non-optimal GB parameters detected for GB model OBC1
#   warnings.warn(
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 12 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 11 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 11 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 0; Notes = 0.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-1.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 23 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-1.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 23 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-1.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 22 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-1.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 22 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-1.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 21 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-1.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 21 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-1.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 21 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-2.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 35 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-2.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 35 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-2.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 34 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-2.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 34 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-2.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 33 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-2.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 33 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-2.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# ...
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-20.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 224 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-21.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 236 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-21.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 236 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-21.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 235 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-21.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 235 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-21.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 234 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-21.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 234 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# -I: Adding /opt/conda/envs/maws/dat/leap/prep to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/lib to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/parm to search path.
# -I: Adding /opt/conda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /opt/conda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2
# ----- Source of /opt/conda/envs/maws/dat/leap/cmd/leaprc.gaff2 done
# Log file: ./leap.log
# Loading parameters: /opt/conda/envs/maws/dat/leap/parm/gaff2.dat
# Reading title:
# AMBER General Force Field for organic molecules (Version 2.2.20, March 2021)
# Loading library: /workspace/data/LIG.lib
# Loading parameters: /workspace/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /opt/conda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-21.002000) is not zero.
#
# /opt/conda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 234 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	LIG	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
