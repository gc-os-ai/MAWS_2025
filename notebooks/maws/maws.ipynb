# %% [markdown]
# # Making Aptamers Without Selex (MAWS)

# %% [markdown]
# ## Description
#
# Welcome to the new version of MAWS! This notebook will guide you through the steps to run MAWS successfully. Please, be aware that the 3d structure prediction of the MAWS generated aptamer is not accurate, so we suggest to use our instructions on notebook `2_aptamer_folding_3dDNA` to generate a better one.
#
# ### INPUT: What do you need to run this notebook?
#
# You only need a **pdb file of your target molecule**, and it can be a protein, small molecule or lipid.
#
# ### OUTPUT: What will you get from this notebook?
#
# You will get the optimal predicted sequence of your aptamer (DNA or RNA) and a **pdb file containing both your target molecule and the aptamer**.
#
# Credits to:
# - The creators of MAWS: [Heidelberg iGEM team (2015)](https://2015.igem.org/Team:Heidelberg/software/maws)
# - The first improvement of the software: [Heidelberg iGEM team (2017)](https://2017.igem.org/Team:Heidelberg/Software/MAWS)
# - The second improvement of the software: [NU Kazakhstan iGEM team (2022)](https://2022.igem.wiki/nu-kazakhstan/software)

# %% [markdown]
# ### REMEMBER: change the Jupyter kernel to **`MAWS`**. See our README file for detailed information.

# %% [markdown]
# ## Define MAWS parameters
#
# You can edit the following cell and change the parameters to run the MAWS program

# %%
# # Job name
# job_name = "maws_aptamer"

# # Number of nucleotides in the aptamer (default: 15)
# nucleotides = 15

# # Path to your pdb file
# my_path = "../../data/1HAO.pdb"

# # Aptamer type (DNA or RNA)
# apt_type = "DNA"

# # Molecule type (protein, organic or lipid)
# mol_type = "protein"

# # Name of your conda environment
# env_name = "maws"

# # Beta (default: 0.01)
# beta = 0.01

# # First chunk size (default: 5000)
# chunk_1 = 5000

# # Second chunk size (default: 5000)
# chunk_2 = 5000

# %%
# !python ../../maws/maws2023.py \
#   --name "{job_name}" \
#   --ntides {nucleotides} \
#   --path "{my_path}" \
#   --aptamertype "{apt_type}" \
#   --moleculetype "{mol_type}" \
#   --beta {beta} \
#   --firstchunksize {chunk_1} \
#   --secondchunksize {chunk_2}

# %%
# Job name
job_name = "1brq_maws_aptamer_final"

# Number of nucleotides in the aptamer (default: 15)
nucleotides = 3

# Path to your pdb file
my_path = "/home/siddharth899/Work/ESOC/MAWS_2025/data/1BRQ.pdb"

# Aptamer type (DNA or RNA)
apt_type = "DNA"

# Molecule type (protein, organic or lipid)
mol_type = "protein"

# Name of your conda environment
env_name = "maws"

# Beta (default: 0.01)
beta = 0.01

# First chunk size (default: 5000)
chunk_1 = 5000

# Second chunk size (default: 5000)
chunk_2 = 5000

# %%
# !python ../../maws/maws2023.py \
  --name "{job_name}" \
  --ntides {nucleotides} \
  --path "{my_path}" \
  --aptamertype "{apt_type}" \
  --moleculetype "{mol_type}" \
  --beta {beta} \
  --firstchunksize {chunk_1} \
  --secondchunksize {chunk_2} \
  --clean-pdb \
  --remove-h \
  --drop-hetatm
# Out:
# /home/siddharth899/Work/ESOC/MAWS_2025/maws/kernels.py:33: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def rotate_kernel(positions, element, axis, angle):
# /home/siddharth899/Work/ESOC/MAWS_2025/maws/kernels.py:111: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def translate_kernel(positions, element, shift):
# /home/siddharth899/Work/ESOC/MAWS_2025/maws/kernels.py:137: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def center_of_mass(positions):
# /home/siddharth899/Work/ESOC/MAWS_2025/maws/kernels.py:155: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def radius(center, positions):
# /home/siddharth899/Work/ESOC/MAWS_2025/maws/kernels.py:175: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def kl_divergence_kernel(sample, reference_sample):
# /home/siddharth899/Work/ESOC/MAWS_2025/maws/kernels.py:204: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def entropy_kernel(sample):
# /home/siddharth899/Work/ESOC/MAWS_2025/maws/kernels.py:230: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def ZPS(sample, beta=0.001):  # noqa: N802
# /home/siddharth899/Work/ESOC/MAWS_2025/maws/kernels.py:261: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   def S(sample, beta=0.001):  # noqa: N802
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./leap.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1BRQ_cleaned.pdb
#   Added missing heavy atom: .R<CASP 175>.A<CA 3>
#   Added missing heavy atom: .R<CASP 175>.A<CB 5>
#   Added missing heavy atom: .R<CASP 175>.A<C 11>
#   Added missing heavy atom: .R<CASP 175>.A<CG 8>
#   Added missing heavy atom: .R<CASP 175>.A<O 12>
#   Added missing heavy atom: .R<CASP 175>.A<OXT 13>
#   Added missing heavy atom: .R<CASP 175>.A<OD1 9>
#   Added missing heavy atom: .R<CASP 175>.A<OD2 10>
#   total atoms in file: 1408
#   Leap added 1352 missing atoms according to residue templates:
#        8 Heavy
#        1344 H / lone pairs
# Checking 'LIG'....
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-5.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.210 angstroms between nonbonded atoms SG and HG
# -------  .R<CYS 4>.A<SG 8> and .R<CYS 160>.A<HG 9>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.387 angstroms between nonbonded atoms HE and HB2
# -------  .R<ARG 5>.A<HE 15> and .R<ARG 5>.A<HB2 6>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.179 angstroms between nonbonded atoms H and HH
# -------  .R<ASP 16>.A<H 2> and .R<TYR 111>.A<HH 15>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.030 angstroms between nonbonded atoms HH11 and HG2
# -------  .R<ARG 19>.A<HH11 18> and .R<ARG 19>.A<HG2 9>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.384 angstroms between nonbonded atoms HZ2 and HH22
# -------  .R<LYS 29>.A<HZ2 19> and .R<ARG 166>.A<HH22 22>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.064 angstroms between nonbonded atoms HB2 and HD12
# -------  .R<LYS 29>.A<HB2 6> and .R<ILE 168>.A<HD12 16>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.278 angstroms between nonbonded atoms HE3 and HB3
# -------  .R<LYS 58>.A<HE3 16> and .R<CYS 174>.A<HB3 7>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.387 angstroms between nonbonded atoms HH11 and HG3
# -------  .R<ARG 62>.A<HH11 18> and .R<ARG 62>.A<HG3 10>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 0.928 angstroms between nonbonded atoms HG and HA
# -------  .R<CYS 70>.A<HG 9> and .R<CYS 174>.A<HA 4>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.387 angstroms between nonbonded atoms H and O
# -------  .R<THR 78>.A<H 2> and .R<LYS 87>.A<O 22>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.246 angstroms between nonbonded atoms OE2 and H
# -------  .R<GLU 81>.A<OE2 13> and .R<GLU 81>.A<H 2>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.472 angstroms between nonbonded atoms HA and HD3
# -------  .R<ASP 82>.A<HA 4> and .R<PRO 83>.A<HD3 4>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.325 angstroms between nonbonded atoms HE1 and HB3
# -------  .R<MET 88>.A<HE1 13> and .R<TYR 90>.A<HB3 7>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.372 angstroms between nonbonded atoms O and HH11
# -------  .R<TYR 111>.A<O 21> and .R<ARG 139>.A<HH11 18>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.481 angstroms between nonbonded atoms O and H
# -------  .R<ALA 115>.A<O 10> and .R<PHE 137>.A<H 2>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.310 angstroms between nonbonded atoms HB1 and HB2
# -------  .R<ALA 115>.A<HB1 6> and .R<PHE 137>.A<HB2 6>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.305 angstroms between nonbonded atoms OE1 and H
# -------  .R<GLU 147>.A<OE1 12> and .R<GLU 147>.A<H 2>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.076 angstroms between nonbonded atoms HH22 and HE
# -------  .R<ARG 153>.A<HH22 22> and .R<ARG 163>.A<HE 15>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.407 angstroms between nonbonded atoms HH12 and HG3
# -------  .R<ARG 153>.A<HH12 19> and .R<ARG 163>.A<HG3 10>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.381 angstroms between nonbonded atoms HG3 and HE22
# -------  .R<ARG 153>.A<HG3 10> and .R<GLN 156>.A<HE22 15>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.494 angstroms between nonbonded atoms HA and HE22
# -------  .R<ARG 153>.A<HA 4> and .R<GLN 156>.A<HE22 15>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.338 angstroms between nonbonded atoms H and H
# -------  .R<GLN 164>.A<H 2> and .R<TYR 165>.A<H 2>
# Checking parameters for unit 'LIG'.
# Checking for bond parameters.
# Checking for angle parameters.
# check:  Warnings: 23
# Unit is OK.
#  Creating LIG.lib
# Building topology.
# Building atom parameters.
# Writing pdb file: LIG_tmp.pdb
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLU -> GLU
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASP -> ASP
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 25; Notes = 0.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source leap.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./leap.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading PDB file: ./1BRQ_cleaned.pdb
#   Added missing heavy atom: .R<CASP 175>.A<CA 3>
#   Added missing heavy atom: .R<CASP 175>.A<CB 5>
#   Added missing heavy atom: .R<CASP 175>.A<C 11>
#   Added missing heavy atom: .R<CASP 175>.A<CG 8>
#   Added missing heavy atom: .R<CASP 175>.A<O 12>
#   Added missing heavy atom: .R<CASP 175>.A<OXT 13>
#   Added missing heavy atom: .R<CASP 175>.A<OD1 9>
#   Added missing heavy atom: .R<CASP 175>.A<OD2 10>
#   total atoms in file: 1408
#   Leap added 1352 missing atoms according to residue templates:
#        8 Heavy
#        1344 H / lone pairs
# Checking 'LIG'....
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-5.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.210 angstroms between nonbonded atoms SG and HG
# -------  .R<CYS 4>.A<SG 8> and .R<CYS 160>.A<HG 9>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.387 angstroms between nonbonded atoms HE and HB2
# -------  .R<ARG 5>.A<HE 15> and .R<ARG 5>.A<HB2 6>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.179 angstroms between nonbonded atoms H and HH
# -------  .R<ASP 16>.A<H 2> and .R<TYR 111>.A<HH 15>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.030 angstroms between nonbonded atoms HH11 and HG2
# -------  .R<ARG 19>.A<HH11 18> and .R<ARG 19>.A<HG2 9>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.384 angstroms between nonbonded atoms HZ2 and HH22
# -------  .R<LYS 29>.A<HZ2 19> and .R<ARG 166>.A<HH22 22>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.064 angstroms between nonbonded atoms HB2 and HD12
# -------  .R<LYS 29>.A<HB2 6> and .R<ILE 168>.A<HD12 16>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.278 angstroms between nonbonded atoms HE3 and HB3
# -------  .R<LYS 58>.A<HE3 16> and .R<CYS 174>.A<HB3 7>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.387 angstroms between nonbonded atoms HH11 and HG3
# -------  .R<ARG 62>.A<HH11 18> and .R<ARG 62>.A<HG3 10>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 0.928 angstroms between nonbonded atoms HG and HA
# -------  .R<CYS 70>.A<HG 9> and .R<CYS 174>.A<HA 4>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.387 angstroms between nonbonded atoms H and O
# -------  .R<THR 78>.A<H 2> and .R<LYS 87>.A<O 22>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.246 angstroms between nonbonded atoms OE2 and H
# -------  .R<GLU 81>.A<OE2 13> and .R<GLU 81>.A<H 2>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.472 angstroms between nonbonded atoms HA and HD3
# -------  .R<ASP 82>.A<HA 4> and .R<PRO 83>.A<HD3 4>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.325 angstroms between nonbonded atoms HE1 and HB3
# -------  .R<MET 88>.A<HE1 13> and .R<TYR 90>.A<HB3 7>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.372 angstroms between nonbonded atoms O and HH11
# -------  .R<TYR 111>.A<O 21> and .R<ARG 139>.A<HH11 18>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.481 angstroms between nonbonded atoms O and H
# -------  .R<ALA 115>.A<O 10> and .R<PHE 137>.A<H 2>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.310 angstroms between nonbonded atoms HB1 and HB2
# -------  .R<ALA 115>.A<HB1 6> and .R<PHE 137>.A<HB2 6>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.305 angstroms between nonbonded atoms OE1 and H
# -------  .R<GLU 147>.A<OE1 12> and .R<GLU 147>.A<H 2>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.076 angstroms between nonbonded atoms HH22 and HE
# -------  .R<ARG 153>.A<HH22 22> and .R<ARG 163>.A<HE 15>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.407 angstroms between nonbonded atoms HH12 and HG3
# -------  .R<ARG 153>.A<HH12 19> and .R<ARG 163>.A<HG3 10>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.381 angstroms between nonbonded atoms HG3 and HE22
# -------  .R<ARG 153>.A<HG3 10> and .R<GLN 156>.A<HE22 15>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.494 angstroms between nonbonded atoms HA and HE22
# -------  .R<ARG 153>.A<HA 4> and .R<GLN 156>.A<HE22 15>
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# Close contact of 1.338 angstroms between nonbonded atoms H and H
# -------  .R<GLN 164>.A<H 2> and .R<TYR 165>.A<H 2>
# Checking parameters for unit 'LIG'.
# Checking for bond parameters.
# Checking for angle parameters.
# check:  Warnings: 23
# Unit is OK.
#  Creating LIG.lib
# Building topology.
# Building atom parameters.
# Writing pdb file: LIG_tmp.pdb
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
#  Converting N-terminal residue name to PDB format: NGLU -> GLU
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
#  Converting C-terminal residue name to PDB format: CASP -> ASP
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 25; Notes = 0.
# /home/siddharth899/miniconda/envs/maws/lib/python3.10/site-packages/openmm/app/internal/amber_file_parser.py:1168: UserWarning: Non-optimal GB parameters detected for GB model OBC1
#   warnings.warn(
# [MAWS] OpenMM platform in use: CUDA
# /home/siddharth899/miniconda/envs/maws/lib/python3.10/site-packages/openmm/app/internal/amber_file_parser.py:1168: UserWarning: Non-optimal GB parameters detected for GB model OBC1
#   warnings.warn(
# [MAWS] OpenMM platform in use: CUDA
# [MAWS] OpenMM platform in use: CUDA
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading library: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.lib
# Loading parameters: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-5.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 618 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CASP	1
# 	NGLU	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# [MAWS] OpenMM platform in use: CUDA
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading library: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.lib
# Loading parameters: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-5.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 618 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CASP	1
# 	NGLU	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# [MAWS] OpenMM platform in use: CUDA
# [MAWS] OpenMM platform in use: CUDA
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading library: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.lib
# Loading parameters: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-6.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 630 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CASP	1
# 	NGLU	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# [MAWS] OpenMM platform in use: CUDA
# [MAWS] OpenMM platform in use: CUDA
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading library: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.lib
# Loading parameters: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-6.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 630 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CASP	1
# 	NGLU	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# [MAWS] OpenMM platform in use: CUDA
# [MAWS] OpenMM platform in use: CUDA
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading library: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.lib
# Loading parameters: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-6.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 629 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CASP	1
# 	NGLU	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# [MAWS] OpenMM platform in use: CUDA
# [MAWS] OpenMM platform in use: CUDA
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading library: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.lib
# Loading parameters: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-6.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 629 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CASP	1
# 	NGLU	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# [MAWS] OpenMM platform in use: CUDA
# [MAWS] OpenMM platform in use: CUDA
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/prep to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/lib to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/parm to search path.
# -I: Adding /home/siddharth899/miniconda/envs/maws/dat/leap/cmd to search path.
# -f: Source out.in.
#
# Welcome to LEaP!
# (no leaprc in search path)
# Sourcing: ./out.in
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.DNA.OL21 done
# Log file: ./leap.log
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/ff-nucleic-OL21.lib
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm10.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/ff-nucleic-OL21.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# OL21 force field for DNA (OL15 + alpha/gamma OL21), see http://ffol.upol.cz
# ----- Source: /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB
# ----- Source of /home/siddharth899/miniconda/envs/maws/dat/leap/cmd/leaprc.protein.ff19SB done
# Log file: ./leap.log
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/parm19.dat
# Reading title:
# PARM99 + frcmod.ff99SB + frcmod.parmbsc0 + OL3 for RNA + ff19SB
# Loading parameters: /home/siddharth899/miniconda/envs/maws/dat/leap/parm/frcmod.ff19SB
# Reading force field modification type file (frcmod)
# Reading title:
# ff19SB AA-specific backbone CMAPs for protein 07/25/2019
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/amino19.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminoct12.lib
# Loading library: /home/siddharth899/miniconda/envs/maws/dat/leap/lib/aminont12.lib
# Loading library: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.lib
# Loading parameters: /home/siddharth899/Work/ESOC/MAWS_2025/data/LIG.frcmod
# Reading force field modification type file (frcmod)
# Reading title:
# Remark line goes here
# Checking Unit.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Warning!
# The unperturbed charge of the unit (-6.000000) is not zero.
#
# /home/siddharth899/miniconda/envs/maws/bin/teLeap: Note.
# Ignoring the warning from Unit Checking.
#
# Building topology.
# Building atom parameters.
# Building bond parameters.
# Building angle parameters.
# Building proper torsion parameters.
# Building improper torsion parameters.
#  total 628 improper torsions applied
# Building H-Bond parameters.
# Incorporating Non-Bonded adjustments.
# Not Marking per-residue atom chain types.
# Marking per-residue atom chain types.
#   (Residues lacking connect0/connect1 -
#    these don't have chain types marked:
#
# 	res	total affected
#
# 	CASP	1
# 	NGLU	1
#   )
#  (no restraints)
# 	Quit
#
# Exiting LEaP: Errors = 0; Warnings = 1; Notes = 1.
# [MAWS] OpenMM platform in use: CUDA
